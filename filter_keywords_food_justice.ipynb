# %%
#######################################
#######################################
#######################################
#######################################
#######################################
# to run a block of code, click on the cell and press control + enter
# a block of code is still running if there's an asterisk to the left
# run this block fo code JUST ONCE
#######################################
#######################################
#######################################
#######################################

# load and optionally install required packages
if (!require('pacman')) install.packages('pacman')
pacman::p_load(
    dplyr,
    readr,
    scales,
    stringr,
    qdapRegex
)

# initial read in of all data
csv_files <- list.files(path='./data/raw/talkwalker', full.names = T, pattern = 'FoodJustice*')
data_groups <- lapply(csv_files, read_csv)
data <- do.call(rbind, data_groups)

# grab only columns we want and rekey some of them for convenience
data.preprocessed <- data %>%
    select(
        # post data
        content,
        domain_url,
        engagement,
        fluency_level,
        images.url,
        lang,
        matched_profile,
        noise_category,
        parent_url,
        porn_level,
        post_type,
        published,
        reach,
        sentiment,
        tags_internal,
        title,
        url,
        url_views = article_extended_attributes.url_views,
        videos.url,
        word_count,
        username = extra_author_attributes.short_name,
        
        # social media data
        facebook_followers = source_extended_attributes.facebook_followers,
        facebook_likes = article_extended_attributes.facebook_likes,
        facebook_shares = article_extended_attributes.facebook_shares,
        twitter_followers = source_extended_attributes.twitter_followers,
        twitter_likes = article_extended_attributes.twitter_likes,
        twitter_retweets = article_extended_attributes.twitter_retweets,
        twitter_shares = article_extended_attributes.twitter_shares,
        instagram_followers = source_extended_attributes.instagram_followers,
        instagram_likes = article_extended_attributes.instagram_likes,
        
        # demographic data
        author_name = extra_author_attributes.name,
        author_birthday = extra_author_attributes.birthdate.date,
        author_birthday_resolution = extra_author_attributes.birthdate.resolution,
        author_gender = extra_author_attributes.gender,
        author_short_name = extra_author_attributes.short_name,
        author_url = extra_author_attributes.url,
        author_description = extra_author_attributes.description,

        # geographic data
        
        author_continent = extra_author_attributes.world_data.continent,
        author_country = extra_author_attributes.world_data.country,
        author_country_code = extra_author_attributes.world_data.country_code,
        author_region = extra_author_attributes.world_data.region,
        author_city = extra_author_attributes.world_data.city,
        article_city = extra_article_attributes.world_data.city,
        article_latitude = extra_article_attributes.world_data.latitude,
        article_longitide = extra_article_attributes.world_data.longitude,
        source_continent = extra_source_attributes.world_data.continent,
        source_country = extra_source_attributes.world_data.country,
        source_country_code = extra_source_attributes.world_data.country_code,
        source_region = extra_source_attributes.world_data.region,
        source_city = extra_source_attributes.world_data.city
    )

# filter ot rows based on various criteria

noise_category_exclusions <- c(
    'real_estate',
    'job_offers',
    'promotions',
    'diet_pharma',
    'hate_speech',
    'seo_scam'
)



exclusion_keywords <- read_csv('./data/raw/exclusion_keywords.csv') %>%
    pull('keyword') %>%
    paste(collapse = '|')




############
## Reverse filtering
############

data.preprocessed <- data.preprocessed %>% filter(
    grepl('Food|Nutrition|Meal|meals|nutritional|diet|dietary', content, ignore.case=TRUE)
)
# Out:
# Loading required package: pacman
#
# Rows: 20276 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14973 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (29): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (1): title
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 16590 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 24907 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 7006 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (29): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (1): title
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 18252 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 16486 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 18196 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 452 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): keyword
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#######################################
#######################################
#######################################
#######################################
#######################################
# run this block EVERY TIME you add new exclusion keywords
#######################################
#######################################
#######################################
#######################################

exclusion_keywords <- paste0(
    exclusion_keywords,
    '|',
    paste(list(
        #################################################
        #################################################
        # insert keywords in the orange area below here
        # only edit below this line
        # make sure last item is NOT followed by comma
        # one keyword per line
        # put a comma after each keyword except the last one
        #################################################
        #################################################
        "Bail reform",
        "Join us at 7:00PM",
        "@Freakonomics",
        "@JInterlandi",
        "criminal justice",
        "application deadline",
        "#WorldSleepDay",
        "#reproductive",
        "One can only hope.",
        "Memoir of a Race Traitor",
        "#WarCrimes",
        "#GetMePPE",
        "#KHive",
        "policing",
        "desensitized to death",
        "#China",
        "Reproductive Health Care",
        "Nigeria",
        "Alteon Health",
        "International Women’s Day",
        "warning about for WEEKS",
        "reproductive freedom",
        "@MAPublicHealth",
        "rich & famous",
        "NYPD",
        "#BailReform",
        "#bailreform",
        "childbirth",
        "@EarthDayNewYork",
        "you better believe capitalism",
        "Eduardo Bonilla-Silva",
        "#Momnibus",
        "Warren dropped out",
        "Maternal Health",
        "North Carolina",
        "imposter syndrome",
        "voter suppression",
        "suicide",
        "all-encompassing",
        "@rachelpowers",
        "#BlackTwitter",
        "protesters",
        "#AMJoy",
        "Georgetown",
        "#RBG",
        "S.F.",
        "ACP Online",
        "Texas Monthly",
        "Africa",
        "reparations",
        "paid sick leave",
        "diet racists",
        "confederate monuments",
        "cardiologist",
        "Rage Becomes Her",
        "satisfying her husband",
        "Register for free",
        "Watts",
        "food for thought",
        "Brazil",
        "#cva",
        "DM me",
        "Reince Priebus",
        "Albany",
        "breast cancer",
        "diet racism",
        "#AbolishPolice",
        "reliant on China",
        "UK",
        "We must flip the senate",
        "Dolphins",
        "Australia",
        "Manchester",
        "Poughkeepsie",
        "diet white",
        "Justice League",
        "#PuertoRico",
        "Hawaii",
        "Food Tech Sector",
        "Arizona",
        "diet of justice",
        "Philly",
        "racist demon food",
        "soap bars",
        "#premed",
        "Toronto",
        "Vegetable Joe",
        "complications related to pregnancy",
        "#curriculumdesign",
        "Dog food",
        "diet devilz",
        "DC",
        "Detroit",
        "Houston",
        "Louisville",
        "USC",
        "MO",
        "#ProudtobeGIM",
        "Nashville",
        "football season",
        "Oregon",
        "Jacksonville",
        "MA",
        "Holyoke",
        "Wayne Ford"
        #################################################
        #################################################
        # no more edits below this line
        #################################################
        #################################################
    ), collapse = '|')
)

data.filtered <- data.preprocessed %>%
    mutate(
        content = str_remove_all(content, pattern = '@\\w+') %>% rm_url()
    ) %>%
    filter(
        !is.na(content),
        length(content) > 15,
        porn_level == 0,
        lang == 'en',
        !noise_category %in% noise_category_exclusions,
        !grepl(exclusion_keywords, content),
        !grepl('\\$SNAP', content)
    )

total_records_raw <- data.preprocessed %>% nrow()
total_records_filtered <- data.filtered %>% nrow()

cat(paste('total raw records:', total_records_raw, '\n'))
cat(paste('records after preprocessing:', total_records_filtered, '\n'))
cat(paste('percent records remaining:', percent(total_records_filtered / total_records_raw)))

set.seed(
    ############################
    ############################
    # change the following seed number to get a different random sample
    # you can use any number
    # run this until you get an average of 90% precision over 5 runs
    ############################
    ############################
    2022
    ############################
    ############################
    # no more edits below this line
    ############################
    ############################
)

data.filtered %>% distinct(content) %>% sample_n(50) #%>% select(content)
data.filtered %>% write_csv('./data/generated/filtered_food_justice.csv');

#######################################
#######################################
#######################################
#######################################
#######################################
# read the random sample below
# calculate your own precision accuracy
# if you want to add more exclusion keywords, go back to the top of this cell, edit it, and run it again
#     you will AUTOMATICALLY get a different random sample of 10
# if you want a different sample to check for precision AND do not want to add to the exclusion keywords,
# change the seed number above and run this cell again
#######################################
#######################################
#######################################
#######################################
# Out:
# total raw records: 13878
# records after preprocessing: 10964
# percent records remaining: 79%
#    content
# 1  Trader Joe's backtracks on ditching 'racist' food brands
# 2  RT : Our city needs access to healthy food, now more than ever. Thank you for joining the fight for food justice. We couldn't do it without you. 🙏 #ThisFoodFights
# 3  RT : Jobs have been lost and people are hungry. The NW Bronx Food Justice Project is right there helping them get food. Sign up here for our newsletter to know more: #nwbronxfoodjustice #foodaccess #bronxcommunityresources #foodinsecurity
# 4  RT : Late last week, 87 U.S.-based farmer organizations and allied agroecology, farm, and food justice groups in delivered a solidarity statement in support of the #FarmersProtest. Read more about this incredible act of solidarity via !
# 5  Burning anything is racist—like this racist blackface food image.
# 6  Black & Brown fast-food workers cannot work from home, we aren’t afforded full-time hours in order to take care of our families, and we cannot take sick days. We are calling for economic and racial justice for fast food workers across the nation! #ProtectAllWorkers
# 7  Food is racist now? I’ll add it to the list.
# 8  Reporter: “Um...is it...Um...is it racist to call Chinese Food...Chinese Food?"
# 9  RT : We hate racists and politicians but let food snobs walk amongst us like it’s no big deal.
# 10 Hey CNN is Chinese food racist? How about Mexican food?
# 11 COVID-19 & systemic racism are public health crises. : invest in services that support all students’ health & well-being. Invest in the Food Ed Hub, SYEP & GrowNYC School Gardens!#FundFoodEd #SaveSYEP
# 12 Y’all really eating the racist food to begin with?? During our month??
# 13 Dude you know how many hispanics stick to their own people and dont befriend people from other cultures. They are not open to American culture (yes I said it again), music, language, food ect. Yet they are not racist. Please 🙄
# 14 RT : Food production costs more than just the cost of business. True Cost Accounting also incorporates environmental, public health, social justice and other costs:
# 15 Join us on Thursday, April 9th from 4pm-6pm for "Food Justice 101 for Youth", an online workshop about the #foodjustice movement, food systems, and how youth #gardeners can take action. For details and to RSVP, visit: #greenthumbgrows #nycparks #gardening
# 16 Watch "Debunking Ayanna Pressley's "Food Apartheid" Mythology" by
# 17 I think Pence should probably take over at this point. Shit info and his insane soliloquy about the media when asked “is Chinese food racist?” should be the last straw.
# 18 RT : #RacismAtTAMUFeelsLike Yt people claiming they’re not racist and “like Mexican food” when in reality they just say that because they eat at Torchy’s and Fuego
# 19 RT : FOOD JUSTICE IN BROOKLYN & NYC Feb 3 10-11:15 AM Register: w/ , , Council of Peoples Organization, , Moderated by Rabbi NY Board of Rabbis Presented by Interfaith United-NYC Coalition
# 20 RT : We demand justice for migrant workers today at the community action at Jane/Finch! ✊🏾🍅🥦 Our fight for food justice must include status for all migrant workers supporting us on the frontlines of this pandemic. #status4all #RealJFActions
# 21 Some dumb bitch just asked if he considers "Chinese food" racist. She's from OAN. I have to change the channel.
# 22 Indra, don't bother kissing up 2 trump. No matter what u do, he will never like a guy like U, probably because he will never feel confortable with ur skin tone, ur accent and the smell of ur food. He is a racist and a white supremacist. U might be racist but U'll never B white
# 23 RT : Making fun of little Black girl who stood up in not allowing people to bastardized her name isn’t being messy, it’s being diet racist.
# 24 RT : In the midst of national struggles with racial injustice & inequities in health care and food access, Native American leaders are calling for a re-examination of the Thanksgiving holiday and its impact on Indigenous communities. via
# 25 Throughout Black History Month this February, City Harvest will recognize and celebrate the Black food justice heroes who have helped lead the fight against hunger for generations. #WeAreCityHarvest
# 26 He said we wouldn’t get a deal , he said it would take years to get a deal with other countries, he said that people who voted leave are racist, he said food prices would go up.. his show is just about Brexit. He’s an intelligent man and should talk about other topics
# 27 Using food as a form of protest has long and storied roots in black communities, and urban farming and the Brownsville free fridge are acts of resistance to the food apartheid that leaves many BIPOC…
# 28 RT : COVID-19 has had a devastating effect on America's Black and Brown communities. Register for our webinar on 6/23 with 's , Brooklyn Borough pres. Eric Adams, and for a discussion on the food system, racism, and health.
# 29 RT : Check out the #FoodVision2050 Visionaries selected by , , & . Ten incredible projects seeking to inspire real, positive, & bold transformation to make food systems regenerative, nourishing, equitable, & sustainable.
# 30 Thanks for the collaboration, ! #DataPrivacy in a World Where #Advertisers Are the Real #Customers and We’re Just Food by
# 31 RT : OAN's , who asked Trump if the term “Chinese food” is racist, is the same one who worked with Giuliani on his conspiracy theory series for OAN. RUFKM #coronavirus #WhiteHouseBriefing
# 32 RT : 📚 Calling all LA-based college students! We’re looking for outgoing and mission-driven leaders to join our Fall 2020 Student Brand Ambassador Program. Help us spread the word about our mission for food justice on your (virtual) campus! #etambassador #backtoschool #thisfoodfights
# 33 Retweeting to raise up these amazing organizations working to fight racism in the food and ag system.
# 34 No justice no food
# 35 OANN reporter asks Trump whether he considers Chinese food racist because it's food that originated from that country
# 36 RT : Welcome back ! We need you to be bold to repair our fractured food system that has left families hungry & communities struggling...to lead the great people of to build back better, more resilient, more equitable, where food is the beginning of a better tomorrow!
# 37 He’s been posting racist tweets since 2014. No Non-Racist Person should spend money at his place of Business. Views like that serving food. I would never eat Food from a Known Racist🤮
# 38 "why cant we have soccer and food ?? we have football and racism"
# 39 RT : Ph.D. graduate Sara Perl Egendorf says studying city soils “opened my eyes to incredible worlds of research and fieldwork supporting social justice and food justice” #GC2020Grads
# 40 RT : What can history teach us about ensuring all Americans have access to nutritious food? Join today at 3:30pm ET for a live conversation exploring the past and present of food justice in America.
# 41 RT : The question, in a time of crisis: "Mr. President, do you consider the term ‘Chinese food’ to be racist because it is food that originated from China?"
# 42 RT : The Covid-19 pandemic has highlighted a major food disparity: while some can order groceries online and reduce their risk of exposure, millions of SNAP recipients can’t. Now, some states want that to change. My (paywall-free) story today for :
# 43 RT : I stand with in strengthening the rights of fast food workers who need and deserve justice in the workplace. Workplace Justice = Just Cause. #ProtectAllWorkers #ServingUpJustice #FightFor15
# 44 RT : The Food team has long discussed more formally crediting original recipe sources. And in June, when a national uproar over police brutality and systemic racism led to an examination of fairness and equity in food media, the idea gained new urgency.
# 45 Martin Frick on the 2021 UN Food Systems Summit: “Nothing defines our interface with nature, and our inequity/equity, more than our food systems” #DaringCities
# 46 RT : Republicans-Republican lawmakers demand answers from Trump on the Russian bounty on American soldiers . Time to give Trump the boot. #FoxNews #truth #VoteTrumpOut #Biden #GOPCorruptionOverCountry #DumpTrump2020 #Food #racism #JoeBiden
# 47 We're showing up because we need 💚Climate Justice 🏥 Medicare for all 🍛 Food security 🏠 Housing for all Why are you showing up?
# 48 The problem is NOT your body. The problem is weight stigma. The problem is fatphobia. The problem is racism. The problem is diet culture. You are deserving of respect and compassion because you are a human being, not because of your health status or pants size.
# 49 Isn’t it so interesting that people will call you classist simply for promoting anti-speciesism? Like as if you can’t also promote food justice reform and accessible plant-based options simultaneously?
# 50 RT : Go to 's IG for the whole breakdown, but this ridiculous piece in the NYT is a masterclass in food racism
