# %%
#######################################
#######################################
#######################################
#######################################
#######################################
# to run a block of code, click on the cell and press control + enter
# a block of code is still running if there's an asterisk to the left
# run this block fo code JUST ONCE
#######################################
#######################################
#######################################
#######################################

# load and optionally install required packages
if (!require('pacman')) install.packages('pacman')
pacman::p_load(
    dplyr,
    readr,
    scales,
    stringr,
    qdapRegex
)

# initial read in of all data
csv_files <- list.files(path='./data/raw/talkwalker', full.names = T, pattern = 'Struggle*')
data_groups <- lapply(csv_files, read_csv)
data <- do.call(rbind, data_groups)

# grab only columns we want and rekey some of them for convenience
data.preprocessed <- data %>%
    select(
        # post data
        content,
        domain_url,
        engagement,
        fluency_level,
        images.url,
        lang,
        matched_profile,
        noise_category,
        parent_url,
        porn_level,
        post_type,
        published,
        reach,
        sentiment,
        tags_internal,
        title,
        url,
        url_views = article_extended_attributes.url_views,
        videos.url,
        word_count,
        username = extra_author_attributes.short_name,
        
        # social media data
        facebook_followers = source_extended_attributes.facebook_followers,
        facebook_likes = article_extended_attributes.facebook_likes,
        facebook_shares = article_extended_attributes.facebook_shares,
        twitter_followers = source_extended_attributes.twitter_followers,
        twitter_likes = article_extended_attributes.twitter_likes,
        twitter_retweets = article_extended_attributes.twitter_retweets,
        twitter_shares = article_extended_attributes.twitter_shares,
        instagram_followers = source_extended_attributes.instagram_followers,
        instagram_likes = article_extended_attributes.instagram_likes,
        
        # demographic data
        author_name = extra_author_attributes.name,
        author_birthday = extra_author_attributes.birthdate.date,
        author_birthday_resolution = extra_author_attributes.birthdate.resolution,
        author_gender = extra_author_attributes.gender,
        author_short_name = extra_author_attributes.short_name,
        author_url = extra_author_attributes.url,
        author_description = extra_author_attributes.description,

        # geographic data
        
        author_continent = extra_author_attributes.world_data.continent,
        author_country = extra_author_attributes.world_data.country,
        author_country_code = extra_author_attributes.world_data.country_code,
        author_region = extra_author_attributes.world_data.region,
        author_city = extra_author_attributes.world_data.city,
        article_city = extra_article_attributes.world_data.city,
        article_latitude = extra_article_attributes.world_data.latitude,
        article_longitide = extra_article_attributes.world_data.longitude,
        source_continent = extra_source_attributes.world_data.continent,
        source_country = extra_source_attributes.world_data.country,
        source_country_code = extra_source_attributes.world_data.country_code,
        source_region = extra_source_attributes.world_data.region,
        source_city = extra_source_attributes.world_data.city
    )

# filter ot rows based on various criteria

noise_category_exclusions <- c(
    'real_estate',
    'job_offers',
    'promotions',
    'diet_pharma',
    'hate_speech',
    'seo_scam'
)

exclusion_keywords <- read_csv('./data/raw/exclusion_keywords.csv') %>%
    pull('keyword') %>%
    paste(collapse = '|')
# Out:
# Loading required package: pacman
#
# Rows: 18518 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (29): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (1): title
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 18675 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1854 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (29): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (1): title
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 15173 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 18917 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 8799 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (27): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (3): title, videos.url, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 15247 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (27): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (3): title, videos.url, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 17745 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (27): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (3): title, videos.url, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 5685 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 19100 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 8632 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 452 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): keyword
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#######################################
#######################################
#######################################
#######################################
#######################################
# run this block EVERY TIME you add new exclusion keywords
#######################################
#######################################
#######################################
#######################################

exclusion_keywords <- paste0(
    exclusion_keywords,
    '|',
    paste(list(
        #################################################
        #################################################
        # insert keywords in the orange area below here
        # only edit below this line
        # make sure last item is NOT followed by comma
        # one keyword per line
        # put a comma after each keyword except the last one
        #################################################
        #################################################
        "#FamiliesFirst",
        "Gun violence",
        "sick leave",
        "coronavirus testing",
        "Zimbabwe",
        "baon",
        "#FamiliesFirstBill",
        "Eva Mendes",
        "economic package",
        "mail carrier",
        "Evangelical",
        "Miami",
        "Obamacare",
        "FEMA",
        "Americans",
        "Voter ID",
        "Freekibble",
        "Congress",
        "TARP",
        "supply chains",
        "Hoboken",
        "Michael Bloomberg",
        "Bangkok",
        "Florida",
        "farmers",
        "irene is so rich",
        "Arizona",
        "#MayThe4th",
        "Africa",
        "Ecuador",
        "Toms River",
        "Jungkook",
        "Italians",
        "#HKers",
        "impeachment",
        "unfettered capitalism",
        "Senate",
        "@GovMurphy",
        "California",
        "LA",
        "Lebanon",
        "Mirai Nagasu",
        "Hobby lobby",
        "@BBCIndia",
        "North Carolina",
        "Michael Jackson",
        "NJ",
        "Fort Lauderdale",
        "Dallas",
        "#JoeBidenIsARacist",
        "Show of Lies",
        "Cultural Revolution",
        "LOSER",
        "hobi",
        "LI",
        "#AltRight",
        "#CommercialRealEstate",
        "@bonappetit",
        "@DanCrenshawTX",
        "#Obamagate",
        "#HeroesAct",
        "welcome the stranger",
        "Amazon jobs",
        "parked illegally",
        "#Georgia",
        "Mitch McConnell",
        "progressive or conservative position",
        "Jackson, Miss",
        "own stock",
        "@RonJohnsonWI",
        "Chinese wife",
        "Elmira",
        "Tesla",
        "#bcorporation",
        "Self Anointing",
        "Long Island",
        "Ron Johnson",
        "super bowl",
        "my struggle food",
        "Jim Jordan",
        "#EconJustice4All",
        "#GivingTuesday2020",
        "#VoteBlueToEndThisNightmare",
        "News Corp",
        "Adigrat",
        "shut down the network",
        "Boeing",
        "#PPP",
        "west coast",
        "Police",
        "Sen Kennedy",
        "family recipe",
        "hospitals are full",
        "#TrumpVirus",
        "#Charlotte",
        "pro life",
        "Elliott",
        "golfing",
        "DC",
        "food industry",
        "SF",
        "Cinnamon Toast Crunch",
        "cut restaurants a tax break",
        "PUTIN",
        "fire every time",
        "#Albertans",
        "District Judge Howell",
        "pro-life",
        "hard time with margins",
        "choose one struggle meal",
        "restaurants are struggling",
        "audiobook",
        "Jesus",
        "#Tripoli",
        "#PMQs",
        "#Hartford",
        "GoogleOrg",
        "live off the system",
        "#BetterWay4Buses",
        "Cape Town",
        "Federal judge",
        "Nigerian households",
        "#HerdMentality",
        "Venezuela",
        "#Amherst",
        "companies",
        "Companies",
        "subscribe",
        "GA",
        "UK",
        "JACK FROSS",
        "Bristol",
        "#MorningJoe",
        "Rockland",
        "vacation days",
        "dementia",
        "#COVID_19uk",
        "Missouri",
        "#TrumpGOPGenocide",
        "YouTube",
        "horses",
        "klapped",
        "Coach Thibs",
        "Lindsey Graham",
        "Syrians",
        "Wisconsin",
        "business suport",
        "SPACE FORCE",
        "Space Force",
        "Google",
        "Las Vegas",
        "struggling local businesses",
        "#ukulele",
        "Hackensack",
        "Texas",
        "#Hollywood",
        "New Jersey",
        "sick donkeys",
        "#Minneapolis",
        "#BirdTwitter"
        #################################################
        #################################################
        # no more edits below this line
        #################################################
        #################################################
    ), collapse = '|')
)

data.filtered <- data.preprocessed %>%
    mutate(
        content = str_remove_all(content, pattern = '@\\w+') %>% rm_url()
    ) %>%
    filter(
        !is.na(content),
        length(content) > 15,
        porn_level == 0,
        lang == 'en',
        !noise_category %in% noise_category_exclusions,
        !grepl(exclusion_keywords, content),
        !grepl('\\$SNAP', content)
    )

total_records_raw <- data %>% nrow()
total_records_filtered <- data.filtered %>% nrow()

cat(paste('total raw records:', total_records_raw, '\n'))
cat(paste('records after preprocessing:', total_records_filtered, '\n'))
cat(paste('percent records remaining:', percent(total_records_filtered / total_records_raw)))

set.seed(
    ############################
    ############################
    # change the following seed number to get a different random sample
    # you can use any number
    # run this until you get an average of 90% precision over 5 runs
    ############################
    ############################
    2022
    ############################
    ############################
    # no more edits below this line
    ############################
    ############################
)

data.filtered %>% distinct(content) %>% sample_n(50) %>% select(content)
data.filtered %>% write_csv('./data/generated/filtered_struggle.csv');
#######################################
#######################################
#######################################
#######################################
#######################################
# read the random sample below
# calculate your own precision accuracy
# if you want to add more exclusion keywords, go back to the top of this cell, edit it, and run it again
#     you will AUTOMATICALLY get a different random sample of 10
# if you want a different sample to check for precision AND do not want to add to the exclusion keywords,
# change the seed number above and run this cell again
#######################################
#######################################
#######################################
#######################################
# Out:
# total raw records: 148345
# records after preprocessing: 48299
# percent records remaining: 33%
#    content
# 1  that’s a struggle meal?? i just ate 3 day old kraft mac and cheese
# 2  RT : The families forced to the streets in the middle of the pandemic, the bereaved relatives, the unemployed, the hungry, the brutalized, and the struggling masses are waiting to be organized together to build the power we need. The power of our people is our only constant
# 3  It’s not elitist when you work in the arts. It’s a full time job. Millions of artists are also struggling for food, work, and healthcare. We are deeply struggling and will be the last to return. It’s unfair of you to not acknowledge that - and disappointing. #artsworkers
# 4  RT : How New York will pair food banks in need with struggling farms, which have excess product
# 5  RT : Vote for Kelly Loeffler and David Perdue if you’d like to be homeless, hungry, and sick.
# 6  RT : Ben Roethlisberger is in a great mood this morning, having fun with the media, including some where who are having struggles getting their live feed working on the zoom call.
# 7  I’m living in nyc and I lost my job because of the pandemic going on, I’m struggling to help my mom with food and our rent is back up. We’ve been selling items on eBay and other sites just to try to get some extra money but it’s not helping because the bills just keep piling up
# 8  RT : When #DonaldTrump walked away from relief negotiations, he abandoned hungry families, shuttered businesses, and struggling students. Our nation’s pain is taking a backseat to his ego.
# 9  A wonderful night - Family Feud Night and youth preparing food for Midnight run to feed the homeless in New York City. Lord be praised!
# 10 RT : Ya’ll like breakfast food? ... 😕 i struggle.
# 11 Additional supports, including $13 billion in extended SNAP (food stamps) benefits & extension of modest unemployment benefits (up to $300/week) may help offset rent burden. Again-the #omnibus is a start & will not alone prevent the #eviction crisis or extreme hardship it creates
# 12 227,000+ dead; up to 40,000,000 facing eviction; 29,000,000 going hungry; at least 12,900,000 unemployed. Is now really the time to declare victory? What happened to the federal stimulus ? #voteMcConnellout #FailedLeadership #hesgoingtodisney
# 13 Good morning. I'm #Homeless and hungry. I have #diabetes and I have to take my medications with food, which I'm unable to. Please help me if you can. Thank you!
# 14 Someone needs to do a video mirror this with ppl waiting in unemployment lines and food lines
# 15 $300+/wk is not enough $600 is not enough Piece-mealing our survival is not right. People are hurting. The state & fed efforts have all been about pitting working class - unemployed v working - & basic rights - food v rent - against eachother. It's ideology not policy.
# 16 he’s going to be broke by June at the rate he wants to feed all the homeless people
# 17 RT : I feel uncomfortable just thinking about biting into an orange like that. I have such a hard time with some food textures and orange/lemon/etc. peel is one of those things.
# 18 I hate gas station videos on tic tok they always fake.they be giving the same homeless man food for like a month.
# 19 RT : Anything that was said or done today by Trump & Company is intended to distract from the numbers: GDP down 33%, 152,000 preventable deaths, 50 mil unemployed, 30 mil going hungry, 3rd straight day record deaths in FL, 32% approval rating, 1 former President calling out his crimes
# 20 RT : Cities Crack Down On Food Delivery App Fees As Restaurants Struggle To Survive
# 21 RT : Congratulations you are a piece of shit of the highest order. If you didn’t kill someone with #COVID19 , you’ll kill them from starvation and homelessness #UnemploymentBenefits #Homeless #food
# 22 Md. nonprofit struggles to address food insecurity during pandemic | WTOP - nonprofit struggles to address food insecurity during pandemic | WTOPMd. nonprofit struggles to address food insecurity during pandemic | WTOP
# 23 RT : Boosting for a 2nd time need for a WCIIA member! "im a sw in chicopee/holyoke mass, im looking to request 50$ emergency funds for a phone bill and winter boots and food I'm 21 and homeless" cashapp $dezzcashh99
# 24 I've chosen to help feed my NYC neighbors struggling with food insecurity. Every $1 helps feed 5 NYers for a day.
# 25 RT : charities will suffer badly - pantries closing due to lack of money, food @ premium. r hurting. unemployed will find food lacking, homeless, poor will suffer, donate if u can.
# 26 RT : It’s no surprise Republicans made it illegal to give water to people in line to vote. They’re the same people who made it illegal to give water to migrants crossing the border. And they’re the same people who make it illegal to feed the homeless. Inhumanity is their shtick.
# 27 Still can’t get over this: Millions unemployed, hungry, soon to be evicted, but that doesn’t even register with this president who thinks of PEOPLE WITH 401Ks as almost some kind of underclass
# 28 RT : Really struggling right now..trying to keep food in the fridge, gas in the car, take care of my two amazing kids and get some necessary bills paid. Anything would help at this time kisses 😔 Truly appreciate it $karissao87
# 29 RT : After six years of civil war in Yemen, a country where two-thirds of the population faces food insecurity, the World Food Program struggles to maintain donor interest, FP's and report.
# 30 RT : 191,000 dead of Covid. 500,000 homeless. 13 million unemployed. 14 million households hungry. 28 million uninsured + an additional 27 million during the pandemic. The rich get richer and the poor die. We need an entirely new economic system.
# 31 Earliest wave of unemployment hit the food service, entertainment and hotel industries. The disruption has since moved into categories including retail, business services, manufacturing and non-essential health care.
# 32 RT : Let none be homeless. Let none go hungry. Let none be uninformed. Let none be drugged, injected, & indebted from birth. By a bunch of low-life psychopaths who deem themselves better than the rest of Mankind. Bottom line? Let none be abused. This shit's gone on for too long.
# 33 RT : While ppl are hoarding food the local Latino grocery/restaurant just announce free meal for anyone struggling cuz of the pandemic. #migente!
# 34 The buck stops with YOU People are SUFFERING because of YOUR incompetence. YOU have NO idea what it feels like to tell your children there is NO FOOD! 😡 FIX THE UNEMPLOYMENT PROBLEM NOW!!!
# 35 RT : I’ve helped mad people move, i just need that meal bro. We struggling to eat out here.
# 36 RT : Kate Middleton and Meghan Markle’s Wedding Gown Maker Struggling to Feed Family​
# 37 the people in the congo struggle with a lack of - food - shelter - schools - enrichment environment for their children to develop their rare & unique talents - shoes - clothes - everything Therefore, as a reparation each Congolese could be started off ~300K Black Currency
# 38 Luke, we can do the debate and all proceeds can go to feed the homeless. At some point it will seem like you are just obfuscating. Let's not get there.
# 39 RT : #PURPLEPOWER we the american people know there is plenty of money to do executive order for stimulis. We are going hungry and homeless. Please help us and help you get reelected
# 40 Distraction Action! Rah! Rah! Rah! Nearly 200k souls dead from CoV2; mils unemployed, facing evictions; too many families struggling to feed their children; anguish over safe school reopening; states facing drastic budget cuts... #TrumpIsToxicWaste
# 41 I’m cryin rn on the train.... a homeless man was eating his food, and another homeless man came on the train and he gave him some of his food🥺
# 42 it’s really discouraging that the people i’m close with have an idea of what they wanna do with their life and i’m still struggling to eat a decent meal everyday 🤣
# 43 RT : Today we start to see the unemployed, real single moms, no food, no meds, and near eviction. They are not the numbers that we read, 52,000,000 unemployed. Real social disorder is coming and Trump might not escape this one, no Fed agents, no Bunker and no way to run.
# 44 AND YOU WILL DO NOTHING .The Democrats always speak death, destruction, high unemployment, food shortages, civil unrest, permanent welfare state! This is who we are up against! Patriots, please follow me aswe fight the New World Order, Chi-com Dems! SCUMBAG!
# 45 Today is #StopFoodWasteDay, & we salute the many organizations providing free meals to anyone who needs them & their efforts to curtail food waste! If you are struggling, please visit Grace Institute’s Participant Resources page to access food resources.
# 46 RT : “A scathing opinion condemned the Agriculture Department attempt to end food stamp benefits for nearly 700,000 unemployed people, blocking as “arbitrary and capricious” the first of three such planned measures to restrict the federal food safety net.”
# 47 The only Tenderloin I care about is where works to "serve hope daily." Help a struggling American get a hot meal by donating here
# 48 Heard they invited some homeless ppl & they ate all their food supplies. Now Aunt Queefa is DEMANDING more food. They're on welfare ALREADY
# 49 Families waiting hours for food. People going to food banks for the first time. Unemployment rates rising. Putting food on the table is harder than it has ever been. Our lawmakers boosting #SNAP benefits by 15% can make it easier: #COVID19 #SNAPMatters
# 50 I hope for the best 🙏🏿🙏🏿 I am indeed of food. I a homeless with 2 daughters. Please someone, help with anything.... I am on my last lap of life😔 $Queenjadea
