# %%
#######################################
#######################################
#######################################
#######################################
#######################################
# to run a block of code, click on the cell and press control + enter
# a block of code is still running if there's an asterisk to the left
# run this block fo code JUST ONCE
#######################################
#######################################
#######################################
#######################################

# load and optionally install required packages
if (!require('pacman')) install.packages('pacman')
pacman::p_load(
    dplyr,
    readr,
    scales,
    stringr,
    qdapRegex
)

# initial read in of all data
csv_files <- list.files(path='./data/raw/talkwalker', full.names = T, pattern = '8FoodInsecurity*')
data_groups <- lapply(csv_files, read_csv)
data <- do.call(rbind, data_groups)

# grab only columns we want and rekey some of them for convenience
data.preprocessed <- data %>%
    select(
        # post data
        content,
        domain_url,
        engagement,
        fluency_level,
        images.url,
        lang,
        matched_profile,
        noise_category,
        parent_url,
        porn_level,
        post_type,
        published,
        reach,
        sentiment,
        tags_internal,
        title,
        url,
        url_views = article_extended_attributes.url_views,
        videos.url,
        word_count,
        username = extra_author_attributes.short_name,
        
        # social media data
        facebook_followers = source_extended_attributes.facebook_followers,
        facebook_likes = article_extended_attributes.facebook_likes,
        facebook_shares = article_extended_attributes.facebook_shares,
        twitter_followers = source_extended_attributes.twitter_followers,
        twitter_likes = article_extended_attributes.twitter_likes,
        twitter_retweets = article_extended_attributes.twitter_retweets,
        twitter_shares = article_extended_attributes.twitter_shares,
        instagram_followers = source_extended_attributes.instagram_followers,
        instagram_likes = article_extended_attributes.instagram_likes,
        
        # demographic data
        author_name = extra_author_attributes.name,
        author_birthday = extra_author_attributes.birthdate.date,
        author_birthday_resolution = extra_author_attributes.birthdate.resolution,
        author_gender = extra_author_attributes.gender,
        author_short_name = extra_author_attributes.short_name,
        author_url = extra_author_attributes.url,
        author_description = extra_author_attributes.description,

        # geographic data
        
        author_continent = extra_author_attributes.world_data.continent,
        author_country = extra_author_attributes.world_data.country,
        author_country_code = extra_author_attributes.world_data.country_code,
        author_region = extra_author_attributes.world_data.region,
        author_city = extra_author_attributes.world_data.city,
        article_city = extra_article_attributes.world_data.city,
        article_latitude = extra_article_attributes.world_data.latitude,
        article_longitide = extra_article_attributes.world_data.longitude,
        source_continent = extra_source_attributes.world_data.continent,
        source_country = extra_source_attributes.world_data.country,
        source_country_code = extra_source_attributes.world_data.country_code,
        source_region = extra_source_attributes.world_data.region,
        source_city = extra_source_attributes.world_data.city
    )

# filter ot rows based on various criteria

noise_category_exclusions <- c(
    'real_estate',
    'job_offers',
    'promotions',
    'diet_pharma',
    'hate_speech',
    'seo_scam'
)

exclusion_keywords <- read_csv('./data/raw/exclusion_keywords.csv') %>%
    pull('keyword') %>%
    paste(collapse = '|')


############
## Reverse filtering
############

data.preprocessed <- data.preprocessed %>% filter(
    grepl('Food Insecurity', content, ignore.case=TRUE)
)
# Out:
# Loading required package: pacman
#
# Rows: 18757 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 19246 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 11353 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 19800 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14586 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14398 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 18169 Columns: 49
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (28): url, published, content, lang, domain_url, parent_url, post_type, ...
# dbl (19): porn_level, fluency_level, sentiment, article_extended_attributes....
# lgl  (2): title, noise_category
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 452 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): keyword
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#######################################
#######################################
#######################################
#######################################
#######################################
# run this block EVERY TIME you add new exclusion keywords
#######################################
#######################################
#######################################
#######################################

exclusion_keywords <- paste0(
    exclusion_keywords,
    '|',
    paste(list(
        #################################################
        #################################################
        # insert keywords in the orange area below here
        # only edit below this line
        # make sure last item is NOT followed by comma
        # one keyword per line
        # put a comma after each keyword except the last one
        #################################################
        #################################################
        "this is an example exclusion keyword",
        "exclusion keyword are case sensitive and literal",
        "Hungry groundhog",
        "losing the best girl",
        "starving for hockey",
        "starving for live big time sports,",
        "finish throwing up",
        "#SouthSudan",
        "COCKSUCKING SLAVE",
"Ayuno en Ciudad de Mexico",
"#South Sudan",
"#KikisDeliveryService",
        "i need to gts but i'm hungry",
"Hungry ticks",
"Onlyfans.com",
"#CashAppBitcoin",
"Power hungry party",
"Manuel Peter Neuer",
"#SolidaridadObrerasForenzi",
        "#China",
"#birdwatching",
"Tigray",
        "President of Hungry",
        "sit on my face",
        "hungry tax assessors",
        "Draft Beers,",
"Chicago",
"Retail investors hungry",
"Hungry kids in the UK",
"Power hungry",
"Sahara reporters",
"Sub-Saharan Africa",
        "hungry for love",
"Hungry chute",
        "#africanow",
"Astrocytes",
"CIA just rebranded",
        "#NIGERIA",
        "Yemen",
"Starving for success",
"Government is always hungry",
        "Kraken will devour trillions",
        "Global warming",
"Power-hungry",
        "Uber Eats",
"Ghana",
"Maniac Cop 2",
"New hex bar max",
        "Riqui and Ansu",
"Tomogunchi",
        "xvids",
        "kids in Boston",
        "McDonalds is still open",
        "fans are hungry for a legit contender",
        "eat past 8",
        "yelled and cried out all my energy",
"XXXL",
"Syrian Army",
        "profit hungry",
        "I drink Prosecco",
        "Ordered food",
        "starving for a start up",
        "COVID_19uk",
        "ORDERS food thru grubhub",
        "FRONTLINE's",
        "rebuild lebanon",
        "Kentuckians",
        "wipe my ass",
        "hungry for a fascist",
        "decimated Beirut",
        "time for AZ to drop an album",
        "hit Venezuela hard",
        "the same shit",
        "aloha burger",
        "i just had dinner",
        "Essex",
        "money hungry",
        "Dick-hungry",
        "give us leadership",
        "huge problem in Beirut",
        "Atlanta",
"Popei’s clam bar",
        "Filipinos",
        "Hungry but lazy",
        "Lays",
        "Michiganders",
        "#Afghanistan",
        "#Niger",
        "New Mexico",
        "Nigeria",
        "Lebanese",
        "LOS ANGELES",
        "Mozambique",
        "Yemeni civil war",
        "#Haiti?",
        "Imran Khan",
        "Arctic",
        "Angola's wild",
        "Houston",
        "Azul Positivo",
        "Syracuse",
        "#MLB",
        "#Yemen",
        "Uganda",
        "Cincinnati Food",
        "Navajo",
        "Southern Africa",
        "Lebanon",
        "Bay State",
        "Utah",
        "Hungry Hungry Hippos",
        "Kenya",
        "Massachussets",
        "Mainers",
        "#Malaysia",
        "Yakima",
        "#SyriaConf21",
        "Cum hungry",
        "rural Oregon",
        "you hungry?"
        #################################################
        #################################################
        # no more edits below this line
        #################################################
        #################################################
    ), collapse = '|')
)

data.filtered <- data.preprocessed %>%
    mutate(
        content = str_remove_all(content, pattern = '@\\w+') %>% rm_url()
    ) %>%
    filter(
        !is.na(content),
        length(content) > 15,
        porn_level == 0,
        lang == 'en',
        !noise_category %in% noise_category_exclusions,
        !grepl(exclusion_keywords, content),
        !grepl('\\$SNAP', content)
    )

total_records_raw <- data %>% nrow()
total_records_filtered <- data.filtered %>% nrow()

cat(paste('total raw records:', total_records_raw, '\n'))
cat(paste('records after preprocessing:', total_records_filtered, '\n'))
cat(paste('percent records remaining:', percent(total_records_filtered / total_records_raw)))

set.seed(
    ############################
    ############################
    # change the following seed number to get a different random sample
    # you can use any number
    # run this until you get an average of 90% precision over 5 runs
    ############################
    ############################
    2023
    ############################
    ############################
    # no more edits below this line
    ############################
    ############################
)

data.filtered %>% distinct(content) %>% sample_n(25) %>% select(content)
data.filtered %>% write_csv('./data/generated/filtered_food_insecurity_8.csv');
#######################################
#######################################
#######################################
#######################################
#######################################
# read the random sample below
# calculate your own precision accuracy
# if you want to add more exclusion keywords, go back to the top of this cell, edit it, and run it again
#     you will AUTOMATICALLY get a different random sample of 10
# if you want a different sample to check for precision AND do not want to add to the exclusion keywords,
# change the seed number above and run this cell again
#######################################
#######################################
#######################################
#######################################
# Out:
# total raw records: 116309
# records after preprocessing: 9446
# percent records remaining: 8%
#    content
# 1  RT : New Yorkers are facing unprecedented unemployment, eviction, food insecurity, and loss of healthcare. We are here to help. CUCS Connects is free and open to all New Yorkers. Connect to see how we can help you access the resources you need at #CUCSConnects
# 2  Wells Fargo helps families in need by turning key locations into drive-up food banks | GMA. Proud to work for a company leveraging locations to address food insecurity #foodbank #foodinsecurity #food #WellsFargoFoodBank
# 3  RT : . critical of GOP senators saying bill they’re getting set to consider doesn’t have money for those suffering from food insecurity, or money to help small businesses.
# 4  While it's tempting to argue from history that a tech is always bad, we encouraged students to consider risks, benefits, & experiences of those affected. For biometrics, we discussed food aid. With 2B people facing food insecurity, can biometrics save lives more efficiently?
# 5  🍎 It's #WorldFoodDay 🍎 Severe levels of food insecurity are much higher for women than men, and are likely to get worse due to the #COVID19 pandemic. Gender equality will help to achieve #ZeroHunger. 🔗
# 6  RT : "Food insecurity is as much about the threat of deprivation as it is about deprivation itself: A food-insecure life means a life lived in fear of hunger, and the psychological toll that takes."
# 7  Our young farmers experience the rewards of working through solutions to eradicate food insecurity. In the process, they transform their relationship to food while helping others improve their relationships with healthy food as well. #Farm2School #F2s
# 8  Active-duty service members and veterans face strikingly high rates of food insecurity and economic hardship — and Trump's deep cuts to SNAP and other food assistance benefits will leave them even worse off. New for
# 9  Glad to see talking at today’s #PlanScapeArch joint conference by about Mental Health impact and trauma caused by COVID , economic hardship, food insecurity , and some hopeful strategies : #openstreets #outdoordining #Parks
# 10 . reports that the has delivered their 100,000th meal to a family dealing with food insecurity during this #CovidCrisis! Check out the full story here: #HealthcareHeroes #CoronavirusResponse #community
# 11 RT : Nice to see compelled to honor despite the US's flirtation with using food insecurity as a weapon of war through extreme sanctions. This method of impoverishing nations & starving the most vulnerable is not so different from the cruder methods used by dictators.
# 12 Report: Pandemic Food Benefits Work To Address Food Insecurity via
# 13 “Food insecurity” is one twisted way of saying starving. Ffs.
# 14 LISTEN LIVE: calls in to our annual #Hungerthon broadcast to discuss food insecurity in New Jersey.
# 15 On behalf of human services agencies across the country, calls for bipartisan action to support a strong and equitable COVID economic recovery, addressing food insecurity, child care, worker supports, family stability, and human services funding:
# 16 Food insecurity. Americans from all walks of life are starving. A generation of children whose education is jeopardized. We are trapped in USA with a monster. The list is long of how Trump wrecked America. He is a negative vortex of evil spinning at home and across the globe.
# 17 RT : 7.5 million infected. 215,000 dead. 26 million on unemployment. 40 million facing eviction. 30% of households face food insecurity. Yet, Trump and the can find the time to confirm judges, but not help people. #stimulus #BidenCares
# 18 Free meals in NYC, no one will be turned away, no ID needed, please let’s spread the word! So many among us are going hungry, food insecurity is a very real thing! Meal Location Search
# 19 RT : 🧼 160,000 masks and supplies to keep people healthy. 🍞 12,600 grocery deliveries to combat food insecurity. 📱 500 devices to close the technology gap. We mobilized to get vital resources to vulnerable people during this pandemic.
# 20 RT : From food insecurity to racial injustice, "Growing Up Poor in America" delves into the issues that children living in poverty in the U.S. are contending with in 2020.
# 21 RT : How do 500k homeless, millions suffering from food insecurity, and "widespread prosperity" work? If one is true, the other two wouldn't exist. #usafacts
# 22 RT : Reminder, as we grapple with skyrocketing bankruptcies, nationwide food insecurity, and mass death on the level of a nuclear strike, that money absolutely is not real
# 23 You can sign up to receive The Shitshow Room for free, but if you do decide to pay, half the proceeds from subscriptions go to charities that help food-service workers and Americans experiencing food insecurity. Read more:
# 24 Food insecurity is a major concern in many African Union Member States as the #COVID19 pandemic continues. 70% of survey respondents reported problems accessing food in the past week. More insights and recommendations in our new #PERCAfrica report:
# 25 RT : Join us for 'A Slide of Humble Pie: Enhancing Sociocultural Humility in Nephrology' #KidneyWk Talks: Dr. Song-ACP, -homelessness, -food insecurity, Dr.Shah -indigenous Other race/equity sessions:
